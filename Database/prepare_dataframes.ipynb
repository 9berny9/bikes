# %%
# !pip install pymysql
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+pymysql://student2:eh2BjVEpYmDcT96E@data.engeto.com:3306/data_academy_02_2022")
query = 'SELECT * FROM edinburgh_weather'

# %%
engine = create_engine("mysql+pymysql://student2:eh2BjVEpYmDcT96E@data.engeto.com:3306/data_academy_02_2022")
query = 'SELECT * FROM edinburgh_weather'

# %%
data = pd.read_sql(sql=query, con=engine)

# %%
data.to_pickle("weather_first.pkl")

# %%
import pandas as pd
df = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/bikes/a_file.pkl")
dfw = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/bikes/w_file.pkl")

# %%
df.info()

# %% [markdown]
# Frekvence měření v jeden den je 8 záznamů, které si upravím a odstraním noční časy
#
# pouze od 6:00 do 21:00

# %%
dfw = dfw[dfw["time"].str.contains("00:00|03:00|06:00")==False]

# %%
dfw["datetime"].month
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3f6a40234a98> in <module>()
# ----> 1 dfw["datetime"].month
#
# NameError: name 'dfw' is not defined

# %%
dfw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3960 entries, 3 to 6335
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      3960 non-null   object
#  1   temp      3960 non-null   object
#  2   feels     3960 non-null   object
#  3   wind      3960 non-null   object
#  4   gust      3960 non-null   object
#  5   rain      3960 non-null   object
#  6   humidity  3960 non-null   object
#  7   cloud     3960 non-null   object
#  8   pressure  3960 non-null   object
#  9   vis       3960 non-null   object
#  10  date      3960 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(10)
# memory usage: 371.2+ KB

# %%
V záznamech nejsou žádné chybějící údaje

# %%
dfw.isna().sum()
# Out:
# time        0
# temp        0
# feels       0
# wind        0
# gust        0
# rain        0
# humidity    0
# cloud       0
# pressure    0
# vis         0
# date        0
# dtype: int64

# %%
dfw.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#          time  temp feels              wind     gust    rain humidity cloud  \
# count    6336  6336  6336              6336     6336    6336     6336  6336
# unique      8    31    32               581       74     106       60   101
# top     00:00  9 °c  6 °c  12 km/h from WSW  26 km/h  0.0 mm      89%  100%
# freq      792   531   471                72      212    4328      300  1285
# first     NaN   NaN   NaN               NaN      NaN     NaN      NaN   NaN
# last      NaN   NaN   NaN               NaN      NaN     NaN      NaN   NaN
#
#        pressure        vis                 date
# ...

# %% [markdown]
# Odstraním feels, wind, humidity, cloud, pressure, vis
#
# nejsou pro mě dulezite

# %%
dfw['wind'].str.extract('(\d+)').astype(float)
# Out:
#          0
# 3     14.0
# 4     15.0
# 5     14.0
# 6     12.0
# 7     11.0
# ...    ...
# 6331  21.0
# 6332  24.0
# 6333  42.0
# 6334  38.0
# 6335  36.0
#
# [3960 rows x 1 columns]

# %%
dfw = dfw.drop(columns=["feels","humidity","cloud","pressure","vis"])

# %%
df2 = dfw.assign(temp_degree = dfw["temp"].str.extract('(\d+)').astype(int),
                 wind_km_h = dfw['wind'].str.extract('(\d+)').astype(int),
                 gust_km_h = dfw["gust"].str.extract('(\d+)').astype(int),
                 rain_mm = dfw["rain"].str.extract('(\d+)').astype(float)
                )

# %%
df2 = df2.drop(columns=["temp","wind","gust","rain"])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3960 entries, 3 to 6335
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   time         3960 non-null   object
#  1   date         3960 non-null   datetime64[ns]
#  2   temp_degree  3960 non-null   int64
#  3   wind_km_h    3960 non-null   int64
#  4   gust_km_h    3960 non-null   int64
#  5   rain_mm      3960 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 216.6+ KB

# %%
df2.groupby("date").mean()
# Out:
#             temp_degree  wind_km_h  gust_km_h  rain_mm
# date
# 2018-09-01         15.4       13.2       20.8      0.0
# 2018-09-02         18.4       16.0       25.0      0.0
# 2018-09-03         11.4        8.6       12.4      0.0
# 2018-09-04         13.6        5.0        6.6      0.0
# 2018-09-05         15.0       11.2       15.8      0.0
# ...                 ...        ...        ...      ...
# 2020-10-27          7.6       16.2       22.2      0.0
# 2020-10-28          7.4       25.0       33.0      0.2
# 2020-10-29          6.8       15.4       24.0      1.8
# 2020-10-30          9.2       15.4       20.4      0.0
# 2020-10-31         11.0       32.2       45.6      0.0
#
# [792 rows x 4 columns]

# %% [markdown]
# Soubor obsahuje 6 336 záznamů od 01.09.2018 – 31.10.2020.

# %% [markdown]
# DF obsahuje 438 259 záznamů od 15.9. 2018 – 30.6 2021.

# %%
df.info()

# %% [markdown]
# Analýza chybějících údajů
# - v databázi nám chybí informace k:
# START_STATION_DESCRIPTION (2710 záznamů)
# END_STATION_DESCRIPTION (3003 záznamů)

# %%
df.isna().sum()

# %%
a = df.loc[ df['start_station_id'] == 247, 'started_at'].min()

# %%
active = df.groupby("start_station_id").count().reset_index()

# %%
active = active.start_station_id[active["started_at"] > 300]

# %%
active
# Out:
# 0       171
# 1       183
# 2       189
# 3       225
# 5       246
#        ...
# 189    1869
# 190    1870
# 194    2259
# 195    2263
# 197    2268
# Name: start_station_id, Length: 145, dtype: int64

# %%
df.isin(active)
# Out:
#         index  started_at  ended_at  duration  start_station_id  \
# 0       False       False     False     False             False
# 1       False       False     False     False             False
# 2       False       False     False     False             False
# 3       False       False     False     False             False
# 4       False       False     False     False             False
# ...       ...         ...       ...       ...               ...
# 438254  False       False     False     False             False
# 438255  False       False     False     False             False
# 438256  False       False     False     False             False
# 438257  False       False     False     False             False
# 438258  False       False     False     False             False
#
#         start_station_name  start_station_description  start_station_latitude  \
# 0                    False                      False                   False
# ...

# %%
df.groupby("start_station_id").agg({'duration' : 'mean', 'started_at' : 'count'}).sort_values(by="started_at").head(40)
# Out:
#                       duration  started_at
# start_station_id
# 1857                296.000000           1
# 1740                770.000000           1
# 241                 100.000000           2
# 1057               1716.000000           2
# 299                1709.000000           3
# 1056              12568.333333           3
# 365                 121.400000           5
# 1032               2368.166667           6
# 964                1600.166667           6
# 980                3354.166667           6
# 1746               4826.000000           9
# 982                3276.727273          11
# 875                2585.666667          18
# 891                1489.157895          19
# 297                2033.842105          19
# 965                1901.565217          23
# 901                1563.880000          25
# 1031               1856.344828          29
# 1040               2783.222222          36
# 883                3066.461538          39
# ...

# %%
df.sort_values(by="started_at")
# Out:
#         index          started_at            ended_at  duration  \
# 0           0 2018-09-15 08:52:05 2018-09-15 09:11:48      1182
# 1           1 2018-09-15 09:24:33 2018-09-15 09:41:09       995
# 2           2 2018-09-15 09:48:54 2018-09-15 10:46:40      3466
# 3           3 2018-09-16 12:01:36 2018-09-16 12:25:26      1430
# 4           4 2018-09-16 12:03:43 2018-09-16 12:11:16       452
# ...       ...                 ...                 ...       ...
# 438254  12636 2021-06-30 23:30:31 2021-07-01 00:06:10      2139
# 438255  12637 2021-06-30 23:36:16 2021-07-01 00:05:40      1763
# 438256  12638 2021-06-30 23:49:03 2021-07-01 00:11:25      1342
# 438257  12639 2021-06-30 23:49:03 2021-07-01 00:11:52      1369
# 438258  12640 2021-06-30 23:58:33 2021-07-01 00:07:15       522
#
#         start_station_id start_station_name         start_station_description  \
# 0                    247   Charlotte Square  North Corner of Charlotte Square
# ...

# %%
df.groupby("start_station_id").count().sort_values(by="index").head(100)
# Out:
#                   index  started_at  ended_at  duration  start_station_name  \
# start_station_id
# 1857                  1           1         1         1                   1
# 1740                  1           1         1         1                   1
# 241                   2           2         2         2                   2
# 1057                  2           2         2         2                   2
# 299                   3           3         3         3                   3
# ...                 ...         ...       ...       ...                 ...
# 344                1007        1007      1007      1007                1007
# 357                1015        1015      1015      1015                1015
# 345                1030        1030      1030      1030                1030
# 1869               1058        1058      1058      1058                1058
# 881                1071        1071      1071      1071                1071
#
# ...
